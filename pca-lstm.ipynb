# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
plt.style.use('fivethirtyeight')
np.random.seed(190)

# %%
#读取数据 
data=pd.read_csv('pca.csv') 
data=data.iloc[:,1:]
windows=3#时间窗长度
cut=100#最后预测的数量
lstm_size=16#lstm的神经元个数
epoch=60#训练次数
validation_split=0.1#验证集所占比例
batch_size=16
data.tail()
# Out:
#             Y1        Y2        Y3        Y4        Y5        Y6        Y7  \
# 1538  6.584669  1.930781  6.342053  1.290249  0.886686 -2.619248 -0.447985
# 1539  3.023501  2.023399  4.574543  1.288856  0.737127 -1.962439 -0.288929
# 1540  1.363457  2.126019  3.516178  1.405804  0.439151 -1.209545 -0.197630
# 1541 -2.985847  2.210498  0.774485  1.374469  0.186726 -0.267314  0.119961
# 1542  8.535188  1.840678  7.005080  1.158901  1.063555 -2.857849 -0.644283
#
#         close
# 1538  2808.53
# 1539  2815.49
# 1540  2810.02
# 1541  2822.44
# 1542  2860.08

# %%
#展示一下看看
plt.figure(figsize=(12,6))
plt.plot(data['close'])

# %%
#区分特征和标签
y=data['close']
del data['close']
x=data
y=np.reshape(y.values, (-1,1))

# %%
#归一化
from sklearn.preprocessing import MinMaxScaler
mm_x= MinMaxScaler()
mm_y= MinMaxScaler()
x= mm_x.fit_transform(x)
y= mm_y.fit_transform(y)

# %%
#构建lstm输入
df=pd.concat([pd.DataFrame(x),pd.DataFrame(y)],axis=1)
stock=df
seq_len=windows
amount_of_features = len(stock.columns)#有几列
data = stock.as_matrix() #pd.DataFrame(stock) 表格转化为矩阵
sequence_length = seq_len + 1#序列长度
result = []
for index in range(len(data) - sequence_length):#循环数据长度-sequence_length次
    result.append(data[index: index + sequence_length])#第i行到i+sequence_length
result = np.array(result)#得到样本，样本形式为6天*3特征
train = result[:-cut, :]
x_train = train[:, :-1]
y_train = train[:, -1][:,-1]
x_test = result[-cut:, :-1]
y_test = result[-cut:, -1][:,-1]
#reshape成 6天*3特征
X_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], amount_of_features))
X_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], amount_of_features))  
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1439, 3, 8) (1439,) (100, 3, 8) (100,)
# E:\anoconda\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
#建立LSTM模型 训练
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
#建立训练模型过程
model = Sequential()#建立层次模型
model.add(LSTM(lstm_size, input_shape=(windows, amount_of_features), return_sequences=False))#建立LSTM层
model.add(Dense(lstm_size,init='uniform',activation='relu'))   #建立全连接层     
model.add(Dense(1,init='uniform',activation='relu'))
model.compile(loss='mse',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_15 (LSTM)               (None, 16)                1600
# _________________________________________________________________
# dense_29 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 1,889
# Trainable params: 1,889
# Non-trainable params: 0
# _________________________________________________________________
# E:\anoconda\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(16, activation="relu", kernel_initializer="uniform")`
#
# E:\anoconda\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="relu", kernel_initializer="uniform")`
#   if __name__ == '__main__':

# %%
#神经网络训练及结果
history= model.fit(X_train, y_train, nb_epoch =epoch, batch_size =batch_size,validation_split=validation_split) #训练模型nb_epoch次
# Out:
# E:\anoconda\lib\site-packages\ipykernel_launcher.py:2: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 1295 samples, validate on 144 samples
# Epoch 1/60
# 1295/1295 [==============================] - 1s 794us/step - loss: 0.0653 - accuracy: 7.7220e-04 - val_loss: 0.0024 - val_accuracy: 0.0000e+00
# Epoch 2/60
# 1295/1295 [==============================] - 0s 152us/step - loss: 0.0173 - accuracy: 0.0015 - val_loss: 0.0102 - val_accuracy: 0.0000e+00
# Epoch 3/60
# 1295/1295 [==============================] - 0s 151us/step - loss: 0.0047 - accuracy: 0.0015 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 4/60
# 1295/1295 [==============================] - 0s 152us/step - loss: 0.0019 - accuracy: 0.0015 - val_loss: 0.0022 - val_accuracy: 0.0000e+00
# Epoch 5/60
# 1295/1295 [==============================] - 0s 141us/step - loss: 0.0012 - accuracy: 0.0015 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 6/60
# 1295/1295 [==============================] - 0s 144us/step - loss: 9.7706e-04 - accuracy: 0.0015 - val_loss: 4.4957e-04 - val_accuracy: 0.0000e+00
# Epoch 7/60
# 1295/1295 [==============================] - 0s 149us/step - loss: 8.7336e-04 - accuracy: 0.0015 - val_loss: 2.4808e-04 - val_accuracy: 0.0000e+00
# Epoch 8/60
# 1295/1295 [==============================] - 0s 149us/step - loss: 7.3761e-04 - accuracy: 0.0015 - val_loss: 6.9281e-04 - val_accuracy: 0.0000e+00
# Epoch 9/60
# 1295/1295 [==============================] - 0s 154us/step - loss: 6.6768e-04 - accuracy: 0.0015 - val_loss: 2.0236e-04 - val_accuracy: 0.0000e+00
# Epoch 10/60
# 1295/1295 [==============================] - 0s 149us/step - loss: 6.1511e-04 - accuracy: 0.0015 - val_loss: 2.0823e-04 - val_accuracy: 0.0000e+00
# Epoch 11/60
# 1295/1295 [==============================] - 0s 208us/step - loss: 5.6286e-04 - accuracy: 0.0015 - val_loss: 1.9478e-04 - val_accuracy: 0.0000e+00
# Epoch 12/60
# 1295/1295 [==============================] - 0s 152us/step - loss: 5.5499e-04 - accuracy: 0.0015 - val_loss: 1.8309e-04 - val_accuracy: 0.0000e+00
# Epoch 13/60
# 1295/1295 [==============================] - 0s 166us/step - loss: 5.5019e-04 - accuracy: 0.0015 - val_loss: 1.9542e-04 - val_accuracy: 0.0000e+00
# Epoch 14/60
# 1295/1295 [==============================] - 0s 156us/step - loss: 5.3600e-04 - accuracy: 0.0015 - val_loss: 3.7009e-04 - val_accuracy: 0.0000e+00
# Epoch 15/60
# 1295/1295 [==============================] - 0s 136us/step - loss: 5.5095e-04 - accuracy: 0.0015 - val_loss: 2.8921e-04 - val_accuracy: 0.0000e+00
# Epoch 16/60
# 1295/1295 [==============================] - 0s 134us/step - loss: 5.1945e-04 - accuracy: 0.0015 - val_loss: 1.8876e-04 - val_accuracy: 0.0000e+00
# Epoch 17/60
# 1295/1295 [==============================] - 0s 134us/step - loss: 5.1860e-04 - accuracy: 0.0015 - val_loss: 2.0565e-04 - val_accuracy: 0.0000e+00
# Epoch 18/60
# 1295/1295 [==============================] - 0s 134us/step - loss: 4.8486e-04 - accuracy: 0.0015 - val_loss: 1.9576e-04 - val_accuracy: 0.0000e+00
# Epoch 19/60
# 1295/1295 [==============================] - 0s 137us/step - loss: 4.7011e-04 - accuracy: 0.0015 - val_loss: 1.9224e-04 - val_accuracy: 0.0000e+00
# Epoch 20/60
# 1295/1295 [==============================] - 0s 129us/step - loss: 4.9869e-04 - accuracy: 0.0015 - val_loss: 3.6304e-04 - val_accuracy: 0.0000e+00
# Epoch 21/60
# 1295/1295 [==============================] - 0s 145us/step - loss: 4.7050e-04 - accuracy: 0.0015 - val_loss: 2.6370e-04 - val_accuracy: 0.0000e+00
# Epoch 22/60
# 1295/1295 [==============================] - 0s 163us/step - loss: 4.8385e-04 - accuracy: 0.0015 - val_loss: 2.3350e-04 - val_accuracy: 0.0000e+00
# Epoch 23/60
# 1295/1295 [==============================] - 0s 154us/step - loss: 4.6714e-04 - accuracy: 0.0015 - val_loss: 1.7360e-04 - val_accuracy: 0.0000e+00
# Epoch 24/60
# 1295/1295 [==============================] - 0s 155us/step - loss: 4.7885e-04 - accuracy: 0.0015 - val_loss: 3.2033e-04 - val_accuracy: 0.0000e+00
# Epoch 25/60
# 1295/1295 [==============================] - 0s 152us/step - loss: 4.5952e-04 - accuracy: 0.0015 - val_loss: 3.6067e-04 - val_accuracy: 0.0000e+00
# Epoch 26/60
# 1295/1295 [==============================] - 0s 144us/step - loss: 4.6816e-04 - accuracy: 0.0015 - val_loss: 2.0944e-04 - val_accuracy: 0.0000e+00
# Epoch 27/60
# 1295/1295 [==============================] - 0s 206us/step - loss: 4.8209e-04 - accuracy: 0.0015 - val_loss: 5.1887e-04 - val_accuracy: 0.0000e+00
# Epoch 28/60
# 1295/1295 [==============================] - 0s 142us/step - loss: 5.1491e-04 - accuracy: 0.0015 - val_loss: 2.8468e-04 - val_accuracy: 0.0000e+00
# Epoch 29/60
# 1295/1295 [==============================] - 0s 138us/step - loss: 4.8686e-04 - accuracy: 0.0015 - val_loss: 2.6207e-04 - val_accuracy: 0.0000e+00
# Epoch 30/60
# 1295/1295 [==============================] - 0s 147us/step - loss: 4.4927e-04 - accuracy: 0.0015 - val_loss: 2.2256e-04 - val_accuracy: 0.0000e+00
# Epoch 31/60
# 1295/1295 [==============================] - 0s 153us/step - loss: 4.5627e-04 - accuracy: 0.0015 - val_loss: 2.1771e-04 - val_accuracy: 0.0000e+00
# Epoch 32/60
# 1295/1295 [==============================] - 0s 162us/step - loss: 4.5776e-04 - accuracy: 0.0015 - val_loss: 5.0313e-04 - val_accuracy: 0.0000e+00
# Epoch 33/60
# 1295/1295 [==============================] - 0s 163us/step - loss: 4.7214e-04 - accuracy: 0.0015 - val_loss: 2.0282e-04 - val_accuracy: 0.0000e+00
# Epoch 34/60
# 1295/1295 [==============================] - 0s 141us/step - loss: 4.7891e-04 - accuracy: 0.0015 - val_loss: 1.7271e-04 - val_accuracy: 0.0000e+00
# Epoch 35/60
# 1295/1295 [==============================] - 0s 152us/step - loss: 4.3971e-04 - accuracy: 0.0015 - val_loss: 2.1045e-04 - val_accuracy: 0.0000e+00
# Epoch 36/60
# 1295/1295 [==============================] - 0s 156us/step - loss: 4.3888e-04 - accuracy: 0.0015 - val_loss: 2.0273e-04 - val_accuracy: 0.0000e+00
# Epoch 37/60
# 1295/1295 [==============================] - 0s 176us/step - loss: 4.4123e-04 - accuracy: 0.0015 - val_loss: 2.3241e-04 - val_accuracy: 0.0000e+00
# Epoch 38/60
# 1295/1295 [==============================] - 0s 154us/step - loss: 4.5260e-04 - accuracy: 0.0015 - val_loss: 4.2661e-04 - val_accuracy: 0.0000e+00
# Epoch 39/60
# 1295/1295 [==============================] - 0s 149us/step - loss: 4.1835e-04 - accuracy: 0.0015 - val_loss: 1.9663e-04 - val_accuracy: 0.0000e+00
# Epoch 40/60
# 1295/1295 [==============================] - 0s 152us/step - loss: 4.3315e-04 - accuracy: 0.0015 - val_loss: 3.6726e-04 - val_accuracy: 0.0000e+00
# Epoch 41/60
# 1295/1295 [==============================] - 0s 136us/step - loss: 4.0016e-04 - accuracy: 0.0015 - val_loss: 2.8491e-04 - val_accuracy: 0.0000e+00
# Epoch 42/60
# 1295/1295 [==============================] - 0s 132us/step - loss: 4.0659e-04 - accuracy: 0.0015 - val_loss: 2.1705e-04 - val_accuracy: 0.0000e+00
# Epoch 43/60
# 1295/1295 [==============================] - 0s 131us/step - loss: 4.2214e-04 - accuracy: 0.0015 - val_loss: 2.0431e-04 - val_accuracy: 0.0000e+00
# Epoch 44/60
# 1295/1295 [==============================] - 0s 129us/step - loss: 4.1917e-04 - accuracy: 0.0015 - val_loss: 1.7736e-04 - val_accuracy: 0.0000e+00
# Epoch 45/60
# 1295/1295 [==============================] - 0s 129us/step - loss: 4.0666e-04 - accuracy: 0.0015 - val_loss: 2.2377e-04 - val_accuracy: 0.0000e+00
# Epoch 46/60
# 1295/1295 [==============================] - 0s 132us/step - loss: 3.9434e-04 - accuracy: 0.0015 - val_loss: 2.2559e-04 - val_accuracy: 0.0000e+00
# Epoch 47/60
# 1295/1295 [==============================] - 0s 136us/step - loss: 3.9833e-04 - accuracy: 0.0015 - val_loss: 2.8538e-04 - val_accuracy: 0.0000e+00
# Epoch 48/60
# 1295/1295 [==============================] - 0s 142us/step - loss: 3.8310e-04 - accuracy: 0.0015 - val_loss: 2.2189e-04 - val_accuracy: 0.0000e+00
# Epoch 49/60
# 1295/1295 [==============================] - 0s 139us/step - loss: 4.0353e-04 - accuracy: 0.0015 - val_loss: 4.8170e-04 - val_accuracy: 0.0000e+00
# Epoch 50/60
# 1295/1295 [==============================] - 0s 128us/step - loss: 4.0825e-04 - accuracy: 0.0015 - val_loss: 2.3996e-04 - val_accuracy: 0.0000e+00
# Epoch 51/60
# 1295/1295 [==============================] - 0s 156us/step - loss: 4.1386e-04 - accuracy: 0.0015 - val_loss: 1.8145e-04 - val_accuracy: 0.0000e+00
# Epoch 52/60
# 1295/1295 [==============================] - 0s 165us/step - loss: 3.7268e-04 - accuracy: 0.0015 - val_loss: 2.0057e-04 - val_accuracy: 0.0000e+00
# Epoch 53/60
# 1295/1295 [==============================] - 0s 186us/step - loss: 3.6996e-04 - accuracy: 0.0015 - val_loss: 2.2866e-04 - val_accuracy: 0.0000e+00
# Epoch 54/60
# 1295/1295 [==============================] - 0s 170us/step - loss: 3.9000e-04 - accuracy: 0.0015 - val_loss: 1.8240e-04 - val_accuracy: 0.0000e+00
# Epoch 55/60
# 1295/1295 [==============================] - 0s 153us/step - loss: 3.8727e-04 - accuracy: 0.0015 - val_loss: 4.4294e-04 - val_accuracy: 0.0000e+00
# Epoch 56/60
# 1295/1295 [==============================] - 0s 183us/step - loss: 4.4941e-04 - accuracy: 0.0015 - val_loss: 1.8047e-04 - val_accuracy: 0.0000e+00
# Epoch 57/60
# 1295/1295 [==============================] - 0s 169us/step - loss: 3.6834e-04 - accuracy: 0.0015 - val_loss: 1.9087e-04 - val_accuracy: 0.0000e+00
# Epoch 58/60
# 1295/1295 [==============================] - 0s 176us/step - loss: 3.5674e-04 - accuracy: 0.0015 - val_loss: 2.6791e-04 - val_accuracy: 0.0000e+00
# Epoch 59/60
# 1295/1295 [==============================] - 0s 162us/step - loss: 3.7306e-04 - accuracy: 0.0015 - val_loss: 3.6889e-04 - val_accuracy: 0.0000e+00
# Epoch 60/60
# 1295/1295 [==============================] - 0s 173us/step - loss: 3.7053e-04 - accuracy: 0.0015 - val_loss: 2.8205e-04 - val_accuracy: 0.0000e+00

# %%
plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='validation')
plt.legend(loc='upper right')
plt.title('Train and Val Loss')
plt.legend()
plt.show()

# %%
#在训练集上的拟合结果
y_train_predict=model.predict(X_train)
# 反归一化
y_train_predict=np.reshape(y_train_predict, (-1,1))  
y_train_predict= mm_y.inverse_transform(y_train_predict)
y_train=np.reshape(y_train, (-1,1))  
y_train=mm_y.inverse_transform(y_train)
#
y_train_predict=y_train_predict[:,0]
draw=pd.concat([pd.DataFrame(y_train),pd.DataFrame(y_train_predict)],axis=1)
draw.iloc[200:500,0].plot(figsize=(12,6))
draw.iloc[200:500,1].plot(figsize=(12,6))
plt.legend(('real', 'predict'),fontsize='15')
plt.title("Train Data",fontsize='30') #添加标题
# Out:
# Text(0.5, 1.0, 'Train Data')

# %%
#在测试集上的预测
y_test_predict=model.predict(X_test)

# 反归一化
y_test_predict=np.reshape(y_test_predict, (-1,1))  
y_test_predict= mm_y.inverse_transform(y_test_predict)
y_test=np.reshape(y_test, (-1,1))  
y_test=mm_y.inverse_transform(y_test)

y_test_predict=y_test_predict[:,0]
draw=pd.concat([pd.DataFrame(y_test),pd.DataFrame(y_test_predict)],axis=1);
draw.iloc[:,0].plot(figsize=(12,6))
draw.iloc[:,1].plot(figsize=(12,6))
plt.legend(('real', 'predict'),loc='upper right',fontsize='15')
plt.title("Test Data",fontsize='30') #添加标题
# Out:
# Text(0.5, 1.0, 'Test Data')

# %%
#输出结果
y_train=y_train.reshape(-1)
y_train_predict=y_train_predict.reshape(-1)
y_test=y_test.reshape(-1)
y_testpredict=y_test_predict.reshape(-1)
def mape(y_true, y_pred):
    return np.mean(np.abs((y_pred - y_true) / y_true)) * 100
def up_down_accuracy(y_true, y_pred):
    y_var_test=y_true[1:]-y_true[:len(y_true)-1]#实际涨跌
    y_var_predict=y_pred[1:]-y_pred[:len(y_pred)-1]#原始涨跌
    txt=np.zeros(len(y_var_test))
    for i in range(len(y_var_test-1)):#计算数量
        txt[i]=np.sign(y_var_test[i])==np.sign(y_var_predict[i])
    result=sum(txt)/len(txt)
    return result
def r_square(y_true, y_pred):
    ssr=sum((y_pred-y_true.mean())**2)
    sst=sum((y_true-y_true.mean())**2)
    return ssr/sst
print('训练集上的MAE/RMSE/MAPE/R-square/涨跌准确率')
print(mean_absolute_error(y_train_predict, y_train))
print(np.sqrt(mean_squared_error(y_train_predict, y_train) ))
print(mape(y_train_predict, y_train) )
print(r_square(y_train_predict, y_train) )
print(up_down_accuracy(y_train_predict,y_train))
print('测试集上的MAE/RMSE/MAPE/R-square/涨跌准确率')
print(mean_absolute_error(y_test_predict, y_test))
print(np.sqrt(mean_squared_error(y_test_predict, y_test) ))
print(mape(y_test_predict,  y_test) )
print(r_square(y_test_predict,  y_test) )
print(up_down_accuracy(y_test_predict,y_test))
# Out:
# 训练集上的MAE/RMSE/MAPE/R-square/涨跌准确率
# 39.161369579704875
# 58.684617814797406
# 1.2456767827693613
# 1.0171543420104925
# 0.5104311543810849
# 测试集上的MAE/RMSE/MAPE/R-square/涨跌准确率
# 47.27359794921875
# 66.84452399684031
# 1.637830028791655
# 1.0935170787668793
# 0.5454545454545454
